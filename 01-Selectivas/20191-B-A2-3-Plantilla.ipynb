# %% [markdown]
# ### Pregunta 3
#
# La empresa Brighstar, líder regional de venta de smartphones, le ha contratado para que desarrolle un programa que permita determinar el precio de venta para cada país:
#
# <table>
# <tr>
#   <td>**País \ Precio**</td>
#   <td>**iPhone**</td>
#   <td>**Samsung**</td>
#   <td>**Huawei**</td>
# <tr>
#   <tr>
#   <td>**Peru**</td>
#   <td>1000</td>
#   <td>650</td>
#   <td>400</td>
# <tr>
# <tr>
#   <td>**Bolivia**</td>
#   <td>1280</td>
#   <td>730</td>
#   <td>550</td>
# <tr>
# <tr>
#   <td>**Chile**</td>
#   <td>1125</td>
#   <td>620</td>
#   <td>380</td>
# <tr>
# </table>
#
# Asimismo, dependiendo del importe total de compra se aplica los siguientes **descuentos**:
#
# <table>
# <tr>
#   <td>**País \ Precio**</td>
#   <td>**Importe total mínimo que aplica descuento**</td>
#   <td>**Descuento**</td>
# <tr>
# <tr>
#   <td>**Perú**</td>
#   <td>9000</td>
#   <td>1.0%</td>
# <tr>
# <tr>
#   <td>**Bolivia**</td>
#   <td>7500</td>
#   <td>1.25%</td>
# <tr>
# <tr>
#   <td>**Chile**</td>
#   <td>8500</td>
#   <td>1.5%</td>
# <tr>
# </table>
#
# Adicionalmente, para promover la venta de la marca **Huawei** se dará el siguiente souvenir cuando se compre como mínimo la siguiente cantidad de equipos Huawei:
#
# <table>
# <tr>
#   <td>**País \ Precio**</td>
#   <td>**Compra minima**</td>
#   <td>**Souvenir**</td>
# <tr>
# <tr>
#   <td>**Perú**</td>
#   <td>5</td>
#   <td>Gorro</td>
# <tr>
# <tr>
#   <td>**Bolivia**</td>
#   <td>6</td>
#   <td>Polo</td>
# <tr>
# <tr>
#   <td>**Chile**</td>
#   <td>7</td>
#   <td>Canguro</td>
# <tr>
# </table>
#
# Se pide lo siguiente:
# 1. Dado un pedido que indica país y cantidad, indicar el **precio final** a pagar.
# 1. Dada una compra de “n” equipos **Huawei** indicar que souvenir se le entregara.

# %%
def calcularPrecioFinal(pais, cant_iphones, cant_samsung, cant_huawei)

end

def calcularSouvenir(pais, cantidad)

end
 

#--- zona de test ----

def test_calcularPrecioFinal
  print validate(5800.00, calcularPrecioFinal("Peru"   , 2, 4, 3)) 
	print validate(6995.00, calcularPrecioFinal("Chile"  , 3, 4, 3)) 
	print validate(9025.75, calcularPrecioFinal("Bolivia", 4, 4, 2)) 
end

def test_calcularSouvenir
  print validate("Gorro"  , calcularSouvenir("Peru"    , 5)) 
	print validate("Ninguno", calcularSouvenir("Chile"  , 5)) 
	print validate("Polo"   , calcularSouvenir("Bolivia", 8)) 
	print validate("Canguro", calcularSouvenir("Chile"  , 7)) 
end
 

def validate (expected, value)
 expected == value ? "." : "F"
end

def test
 
  puts "Test de prueba del programa"
  puts "---------------------------"
  test_calcularPrecioFinal
  test_calcularSouvenir 
  puts " "
  
end
test
# Out:
# Test de prueba del programa
# ---------------------------
# FFFFFFF
